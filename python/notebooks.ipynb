# %%
import fairgraph

# %%
from fairgraph import KGClient

kg_client = KGClient(host="core.kg.ebrains.eu")
kg_client.user_info()
# Out:
# ************************************************************************
# To continue, you need to authenticate. To do so, please visit https://iam.ebrains.eu/auth/realms/hbp/device?user_code=ZPYA-MTDJ
# *************************************************************************
# You are successfully authenticated! Thank you very much!
# *************************************************************************
# User(alternate_name='mayakobchenko', name='Maya Kobchenko', email=None, given_name='Maya', family_name='Kobchenko', identifiers=['7aec2bf2-82c8-40c1-bd64-173cabcfd842'])

# %%
from fairgraph import KGClient
token = input("Enter token:")
# Out:
# Enter token:eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJLYU01NTRCM2RmMHBIamZYWi1aRl94bUUwMThPS1R0RkNjMjR3aVVqQmFvIn0.....SJKoT0YlHqWiFPkPo0cV2RI-iEvzEcAY0gpeLVVgzmpwIe8ZLd1qS9-pmTIuIgsxwc3B0wYgE8_xKe7k5n-Trr0vdRHIZ8DzQUwNgYI4Jrp8SXJBk0egduZJwbgcX6O_e3Rf0rQlDAfLweRDQAW92kYKNuc-b0TBhDOO7M2HFymU3nmapSUqHRcBOk6WE-Lgd3180KsokCRL4UeqOybY3K5UbXFByWk-MR8_VtGWzkhqPHx4zCFKDuFx-_ue5FGugFXCyf2urNOzoKSMLwsrwICGRaGkR0sHNFSJHe9OjDORWLSbybuEEY24kXe5H70qFil4r2mG8KN4A4d4z05LqA

# %%
client = KGClient(token, host="core.kg.ebrains.eu")

# %%
from fairgraph.openminds.core import Subject, DatasetVersion, SubjectState
help(DatasetVersion)
# Out:
# Help on class DatasetVersion in module fairgraph.openminds.core.products.dataset_version:
#
# class DatasetVersion(fairgraph.kgobject.KGObject)
# ...

# %%
dataset_version_uuid = "724d4af0-fe28-4032-8837-120b0d64a81c"

# %%
dataset_uuid = "569d4995-f7c2-4939-8214-db431e78ae23"

# %%
DSV = fairgraph.openminds.core.Dataset.from_id(dataset_uuid, client, scope="in progress")

# %%
DSV.show(include_empty_properties=True)
# Out:
# id                  https://kg.ebrains.eu/api/instances/569d4995-f7c2-4939-8214-db431e78ae23
# space               collab-d-724d4af0-fe28-4032-8837-120b0d64a81c
# type                https://openminds.ebrains.eu/core/Dataset
# authors             None
# custodians          None
# description         None
# digital_identifier  None
# full_name           Maya's test collab
# has_versions        KGProxy([<class 'fairgraph.openminds.core.products.dataset_version.DatasetVersion'>], 'https://kg.ebrains.eu/api/instances/724d4af0-fe28-4032-8837-120b0d64a81c')
# homepage            None
# how_to_cite         None
# short_name          None
# comments            KGQuery([<class 'fairgraph.openminds.core.miscellaneous.comment.Comment'>], {'about': 'https://kg.ebrains.eu/api/instances/569d4995-f7c2-4939-8214-db431e78ae23'})
# ...

# %%
dataset_version_uuid_Archana = "517af2d1-897a-43eb-8bd1-48b81e1d1556"

# %%
DSV_Archana = fairgraph.openminds.core.DatasetVersion.from_id(dataset_version_uuid_Archana, client, scope="in progress")
# Out:
# Property 'accessibility' is required but was not provided.
# Property 'data_types' is required but was not provided.
# Property 'digital_identifier' is required but was not provided.
# Property 'ethics_assessment' is required but was not provided.
# Property 'full_documentation' is required but was not provided.
# Property 'license' is required but was not provided.
# Property 'release_date' is required but was not provided.
# Property 'version_identifier' is required but was not provided.
# Property 'version_innovation' is required but was not provided.

# %%
DSV_Archana.show()
# Out:
# id                       https://kg.ebrains.eu/api/instances/517af2d1-897a-43eb-8bd1-48b81e1d1556
# space                    dataset
# type                     https://openminds.ebrains.eu/core/DatasetVersion
# experimental_approaches  KGProxy([<class 'fairgraph.openminds.controlled_terms.experimental_approach.ExperimentalApproach'>], 'https://kg.ebrains.eu/api/instances/999b93c3-c8f7-4739-af04-198b496cf20f')
# full_name                This is an awesome dataset
# short_name               FAIRGRAPH_practice
# ...
